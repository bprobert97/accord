# %% [markdown]
# # Thoughts
# Options are:
# 1. Satellites send their own positional and trajectory info, along with IDs of any satellites they witness
#     - No external measurements needed, just basic witnessing
#     - Satellite A reports: ' I saw satellite B and here is my positional data'. Satellite B reports 'I saw satellite A and here is my positional data'. Can verify that these are correct within a certain error tolerance. Is it mathematically possible they saw each other?
# 2. Satellites send the position and and velocity info of a satellite they witness
#     - Requires accurate measurement of another satellite's position and velocity from another satellite. Not sure every satellite can do this.
#     - Stronger witnessing, but larger data set to send.
#
# - Need to consider doppler shift, TLE data, how can satellites actually witness each other? Through ISLs and broadcasting?
# - Could it be verified against existing ground data to begin with? Then moved away with ground as a back up for redundancy?
# - What calculations would need to be performed?
# - Incentivised to provide honest information with reputation score, then consensus reached later.
# - Use cases: Invalid info, valid but incorrect info: https://docs.xyo.network/XYO-White-Paper.pdf (Sections 4.2 and 4.3)
# - Do I want a constant chain, or a chain that gets queried and then develops? An API? How will users interact? (Maybe a question for later)
# - XYO - do I need a signature? What if the node is compromised? I guess maybe it tells me it is?
# - p2p sims: https://datatracker.ietf.org/doc/draft-jesus-gfds/00/ https://ieeexplore.ieee.org/document/9996836
#
# # References
# * https://github.com/samuelxu999/EconLedger/blob/main/src/consensus/ENF_consensus.py
# * https://github.com/helium/oracles/blob/main/iot_verifier/src/poc.rs
# * https://www.swirlds.com/downloads/SWIRLDS-TR-2016-01.pdf
# * https://docs.helium.com/iot/proof-of-coverage-roadmap
# * https://www.researchgate.net/publication/379723426_Decentralized_And_Neutral_Consensus_Mechanisms_in_Space_Conjunctions_Assessment_and_Mitigation_Space_DAO_STM - similar work but for different applications thus far (STM is up and coming)
# * https://www.sciencedirect.com/science/article/pii/S0094576524003308
# * https://www.mdpi.com/2504-446X/6/2/34
# * https://www.mdpi.com/1996-1073/12/18/3570
# * https://www.linkedin.com/posts/spacecoin-official_proof-of-location-activity-7336127810270375937-TX8U/
# * https://spacecoin.org/
# * decentralized physical infrastructure network: https://ieeexplore.ieee.org/document/10737386
# * https://docs.hivemapper.com/, https://geodnet.com/
# * https://docs.natix.network/whitepaper/natix-network-ecosystem/data-validation
# * location verification first emerged in 2016: https://docs.xyo.network/XYO-White-Paper.pdf (Sections 2, 4.2 and 4.3)
# * https://www.ncdps.gov/division/emergency-management/ts-helene-after-action-review/open (page 3)
# * Celestrak citation: https://celestrak.org/NORAD/elements/index.php?FORMAT=json
# * DAG sims: https://github.com/iotaledger-archive/TangleSim and https://medium.com/coinmonks/simple-directed-acyclic-graph-iota-like-implementation-in-python-8e07677c55b5 and https://github.com/i13-msrg/cidds
# * page 13: https://www.rand.org/pubs/research_reports/RRA3822-1.html for network structure reflecting state of governance (nodes more than transactions)
# * https://ieeexplore.ieee.org/document/9881803/ Philos
# * A. Abdui-Rahman, S. Hailes, and S. Hailes, “A Distributed Trust Model”. - trust categories; treating satellites as family to affect trust, maybe? zero trust between constellations, or just between everything regardless of constellation? do i trust anyone? are nodes indiviudals or families -do families save time? is that a good model?
# * http://arxiv.org/abs/1906.11461 - fantastic paper on trust for iot sensors. need to find more
# * https://ieeexplore.ieee.org/document/9422738/, gompertz function and impact of weighting factors (liek time decay) in results.
# * A. Jøsang and R. Ismail, “The Beta Reputation System”. discounting, forgetting, engines and propogation (ebay)
# * https://ieeexplore.ieee.org/document/7038144/ underwater acoustic sensor networks - v cool
# * https://www.sciencedirect.com/science/article/pii/S0094576523002527 - COOPERATIVE OD
# * https://spectrum.ieee.org/data-integrity
# * https://gitlab.imt-atlantique.fr/iota-imt/goshimmer/-/blob/test-masterpow/docs/protocol_specification/tangle.md#orphanage--approval-switch - IOTA Tangle approval switch
# * https://github.com/iotaledger-archive/IOTA-2.0-Research-Specifications/blob/main/4.1%20The%20Tangle.md - IOTA Tangle approval switch
# * https://gist.github.com/stkubr/0469ab30b1f992e2817f6060e4bf576f and https://medium.com/coinmonks/simple-directed-acyclic-graph-iota-like-implementation-in-python-8e07677c55b5 - simple DAG in Python
# * https://www.linkedin.com/posts/jahniverse_epistemic-trust-kernel-shared-stewardship-ugcPost-7356041622796599297-uCMd/?utm_source=share&utm_medium=member_desktop&rcm=ACoAABHGnNsB47ohCUQjr5golV_YCMLoSGr7wCE great post that outlines the vision. Also discusses zero trust. DLTs can add to this.
# * https://slab.stanford.edu/projects/starling (to add, synchronised small swarm rather than async, but a good start)
# * https://arc.aiaa.org/doi/10.2514/1.I011576 cognitive vs statistical trust, Elo score, clusters of nodes rather than all nodes, centralised with management nodes in each cluster
# * https://www.researchgate.net/profile/Brendan-Hall/publication/226020071_Byzantine_Fault_Tolerance_from_Theory_to_Reality/links/5444f2570cf2a76a3ccdc6fc/Byzantine-Fault-Tolerance-from-Theory-to-Reality.pdf byzantine fault definition and region (as per my reputation graph. Byzantine fault: a fault presenting different symptoms to different observers.) Says how often byzantine faults occur. 1st paragraph of section 6 - filtering approach is mine (and a bit of full exchange?) Section 6.4
# * https://arc.aiaa.org/doi/10.2514/1.G005439 filters, propogation and gaussian assumption
# * https://arc.aiaa.org/doi/10.2514/1.A35598 Importance of smart contracts (no ground segment for commands) Observability considerations page 9. Fig 9 is cool. Want errors to converge
# * GOOD PAPER: https://arc.aiaa.org/doi/epdf/10.2514/1.G003503consensus providing collectuve observability when single is not enough, small relative distance lower order ok (above eq 5). Questions the linearity of my system - is higher order needed?. Look at pages 304 for equations on CEKF (conensus EKF). Consensus feeds back into the filtering - could I do this?? Fig 8.
